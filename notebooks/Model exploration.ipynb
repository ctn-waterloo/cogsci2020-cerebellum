# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import seaborn
import pytry

import sys
sys.path.append('../model')

import blink_trial
import importlib

# %%
importlib.reload(blink_trial)

plt.figure(figsize=(14,9))
r = blink_trial.BlinkTrial().run(plt=plt, n_trials=200, data_dir=None, verbose=False)
# Out:
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# <script>
#               (function () {
#                   var root = document.getElementById('306799a1-fd3e-4f92-b16c-5dedbf37b24e');
#                   var text = root.getElementsByClassName('pb-text')[0];
#                   var fill = root.getElementsByClassName('pb-fill')[0];
#
#                   text.innerHTML = 'Build finished in 0:00:01.';
#
#             fill.style.width = '100%';
#             fill.style.animation = 'pb-fill-anim 2s linear infinite';
#             fill.style.backgroundSize = '100px 100%';
#             fill.style.backgroundImage = 'repeating-linear-gradient(' +
#                 '90deg, #bdd2e6, #edf2f8 40%, #bdd2e6 80%, #bdd2e6)';
#
#
#                 fill.style.animation = 'none';
#                 fill.style.backgroundImage = 'none';
#
#               })();
# ...

# %%
print(blink_trial.BlinkTrial().show_params())
# Out:
#     do_minimal: only run minimal model (default=True)
#       eye_bias: eyelid opening constant (default=4)
#  learning_rate: learning rate (default=0.0001)
#      n_granule: number of granule cells (default=50)
#       n_trials: number of trials (default=4)
#         period: time between trials (default=0.8)
#              q: q (default=6)
#   sample_every: probe resolution (default=0.001)
# save_plot_data: save data from plots (default=True)
#           seed: random number seed (default=1)
#        t_delay: time between tone and puff (default=0.1)
#         t_puff: puff length (default=0.1)
#         t_tone: tone length (default=0.1)
#            tau: tau for granule (default=0.1)
#      tau_error: tau for error feedback (default=0.2)
#        tau_pre: tau for learning rule (default=0.2)
#   tau_purkinje: tau for purkinje output (default=0.01)
#          theta: theta (default=0.4)
#     use_cosine: use cosine intercept distribution (default=True)
# ...
